# %%
import pandas as pd
import numpy as np

# %%
# Save path to data set in a variable (.tsv files)
title_basics_file = "../Resources/title_basics.tsv"
title_akas_file = "../Resources/title_akas.tsv"
title_principals_file = "../Resources/title_principals.tsv"
title_ratings_file = "../Resources/title_ratings.tsv"
name_basics_file = "../Resources/name_basics.tsv"

# %%
# Read the original data files (.tsv files)
title_basics_df= pd.read_csv(title_basics_file, sep='\t')
title_basics_df
# Out:
# C:\Users\Joe\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6321297  tt9916848  tvEpisode              Episode #3.17
# 6321298  tt9916850  tvEpisode              Episode #3.19
# 6321299  tt9916852  tvEpisode              Episode #3.20
# 6321300  tt9916856      short                   The Wind
# 6321301  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894      \N              1
# 1           Le clown et ses chiens        0      1892      \N              5
# 2                   Pauvre Pierrot        0      1892      \N              4
# 3                      Un bon bock        0      1892      \N             \N
# 4                 Blacksmith Scene        0      1893      \N              1
# ...                            ...      ...       ...     ...            ...
# 6321297              Episode #3.17        0      2010      \N             \N
# 6321298              Episode #3.19        0      2010      \N             \N
# 6321299              Episode #3.20        0      2010      \N             \N
# 6321300                   The Wind        0      2015      \N             27
# 6321301  Horrid Henry Knows It All        0      2014      \N             10
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 6321297       Action,Drama,Family
# 6321298       Action,Drama,Family
# 6321299       Action,Drama,Family
# 6321300                     Short
# 6321301   Animation,Comedy,Family
#
# [6321302 rows x 9 columns]

# %%
##Clean up content, drop adult movies
title_basics_clean = title_basics_df.loc[title_basics_df['isAdult']==0]

##Drop unnecessary columns (isAdult)
title_basics_clean = title_basics_clean.drop(['isAdult'], axis=1)

##Rename columns
title_basics_clean = title_basics_clean.rename(columns={"tconst":"titleId","titleType":"Type"})

#Replace \N w/ NaN
title_basics_clean = title_basics_clean.replace('\\N', 'N\A')

#title_basics_clean.drop_index
title_basics_clean = title_basics_clean.set_index(["titleId"])

title_basics_clean
# Out:
#                 Type               primaryTitle              originalTitle  \
# titleId
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short             Pauvre Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#           startYear endYear runtimeMinutes                    genres
# titleId
# tt0000001      1894     N\A              1         Documentary,Short
# tt0000002      1892     N\A              5           Animation,Short
# tt0000003      1892     N\A              4  Animation,Comedy,Romance
# tt0000004      1892     N\A            N\A           Animation,Short
# tt0000005      1893     N\A              1              Comedy,Short
# ...             ...     ...            ...                       ...
# tt9916848      2010     N\A            N\A       Action,Drama,Family
# tt9916850      2010     N\A            N\A       Action,Drama,Family
# tt9916852      2010     N\A            N\A       Action,Drama,Family
# tt9916856      2015     N\A             27                     Short
# tt9916880      2014     N\A             10   Animation,Comedy,Family
#
# [6132235 rows x 7 columns]

# %%
#Review the data
title_basics_clean.describe()
# Out:
#              Type  primaryTitle originalTitle startYear  endYear  \
# count     6132235       6132225       6132225   6132235  6132235
# unique         10       3007804       3023387       247       94
# top     tvEpisode  Episode #1.1  Episode #1.1       N\A      N\A
# freq      4345916         33464         33464    369326  6078052
#
#        runtimeMinutes   genres
# count         6132235  6132235
# unique            797     2130
# top               N\A    Drama
# freq          4338375   610618

# %%
# Read the original data files (.tsv files)
#title_akas_df= pd.read_csv(title_akas_file, sep='\t')
#title_akas_df

##Not using akas file for current project.

# %%
# Read the original data files (.tsv files)
title_principals_df= pd.read_csv(title_principals_file, sep='\t')
title_principals_df
# Out:
#              tconst  ordering     nconst         category  \
# 0         tt0000001         1  nm1588970             self
# 1         tt0000001         2  nm0005690         director
# 2         tt0000001         3  nm0374658  cinematographer
# 3         tt0000002         1  nm0721526         director
# 4         tt0000002         2  nm1335271         composer
# ...             ...       ...        ...              ...
# 36468812  tt9916880         5  nm0996406         director
# 36468813  tt9916880         6  nm1482639           writer
# 36468814  tt9916880         7  nm2586970           writer
# 36468815  tt9916880         8  nm1594058         producer
# 36468816  tt9916880         9  nm2676923          actress
#
#                               job  \
# 0                              \N
# 1                              \N
# 2         director of photography
# 3                              \N
# 4                              \N
# ...                           ...
# 36468812       principal director
# 36468813                       \N
# 36468814                    books
# 36468815                 producer
# 36468816                       \N
#
#                                                  characters
# 0                                               ["Herself"]
# 1                                                        \N
# 2                                                        \N
# 3                                                        \N
# 4                                                        \N
# ...                                                     ...
# 36468812                                                 \N
# 36468813                                                 \N
# 36468814                                                 \N
# 36468815                                                 \N
# 36468816  ["Sour Susan","Goody-Goody Gordon","Singing So...
#
# [36468817 rows x 6 columns]

# %%
##Rename columns
title_principals_df = title_principals_df.rename(columns={"tconst":"titleId","nconst":"nameId"})

##Drop unnecessary columns (ordering)
title_principals_df = title_principals_df.drop(['ordering','job'], axis=1)

#Replace \N w/ N\A
title_principals_df = title_principals_df.replace('\\N', 'N\A')

#title_basics_clean.drop_index
title_principals_df = title_principals_df.set_index(["titleId"])

title_principals_df
# Out:
#               nameId         category  \
# titleId
# tt0000001  nm1588970             self
# tt0000001  nm0005690         director
# tt0000001  nm0374658  cinematographer
# tt0000002  nm0721526         director
# tt0000002  nm1335271         composer
# ...              ...              ...
# tt9916880  nm0996406         director
# tt9916880  nm1482639           writer
# tt9916880  nm2586970           writer
# tt9916880  nm1594058         producer
# tt9916880  nm2676923          actress
#
#                                                   characters
# titleId
# tt0000001                                        ["Herself"]
# tt0000001                                                N\A
# tt0000001                                                N\A
# tt0000002                                                N\A
# tt0000002                                                N\A
# ...                                                      ...
# tt9916880                                                N\A
# tt9916880                                                N\A
# tt9916880                                                N\A
# tt9916880                                                N\A
# tt9916880  ["Sour Susan","Goody-Goody Gordon","Singing So...
#
# [36468817 rows x 3 columns]

# %%
#Review the data
title_principals_df.describe(include = 'all')
# Out:
#            nameId  category characters
# count    36468817  36468817   36468817
# unique    3871313        12    2206761
# top     nm0438471     actor        N\A
# freq        16465   8493701   17944106

# %%
# Read the original data files (.tsv files)
title_ratings_df= pd.read_csv(title_ratings_file, sep='\t')
title_ratings_df
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000001            5.6      1550
# 1       tt0000002            6.1       186
# 2       tt0000003            6.5      1207
# 3       tt0000004            6.2       113
# 4       tt0000005            6.1      1934
# ...           ...            ...       ...
# 993148  tt9916576            5.9         7
# 993149  tt9916578            9.1        11
# 993150  tt9916720            5.1        41
# 993151  tt9916766            6.7        11
# 993152  tt9916778            6.9        16
#
# [993153 rows x 3 columns]

# %%
##Rename columns
title_ratings_df = title_ratings_df.rename(columns={"tconst":"titleId"})

#title_basics_clean.drop_index
title_ratings_df = title_ratings_df.set_index(["titleId"])

title_ratings_df
# Out:
#            averageRating  numVotes
# titleId
# tt0000001            5.6      1550
# tt0000002            6.1       186
# tt0000003            6.5      1207
# tt0000004            6.2       113
# tt0000005            6.1      1934
# ...                  ...       ...
# tt9916576            5.9         7
# tt9916578            9.1        11
# tt9916720            5.1        41
# tt9916766            6.7        11
# tt9916778            6.9        16
#
# [993153 rows x 2 columns]

# %%
#Review the data
title_ratings_df.describe()
# Out:
#        averageRating      numVotes
# count  993153.000000  9.931530e+05
# mean        6.886546  9.556980e+02
# std         1.400235  1.565733e+04
# min         1.000000  5.000000e+00
# 25%         6.100000  9.000000e+00
# 50%         7.100000  2.000000e+01
# 75%         7.900000  7.600000e+01
# max        10.000000  2.159745e+06

# %%
# Read the original data files (.tsv files)
name_basics_df= pd.read_csv(name_basics_file, sep='\t')
name_basics_df
# Out:
#             nconst         primaryName birthYear deathYear  \
# 0        nm0000001        Fred Astaire      1899      1987
# 1        nm0000002       Lauren Bacall      1924      2014
# 2        nm0000003     Brigitte Bardot      1934        \N
# 3        nm0000004        John Belushi      1949      1982
# 4        nm0000005      Ingmar Bergman      1918      2007
# ...            ...                 ...       ...       ...
# 9706917  nm9993714   Romeo del Rosario        \N        \N
# 9706918  nm9993716       Essias Loberg        \N        \N
# 9706919  nm9993717  Harikrishnan Rajan        \N        \N
# 9706920  nm9993718         Aayush Nair        \N        \N
# 9706921  nm9993719          Andre Hill        \N        \N
#
#                            primaryProfession  \
# 0             soundtrack,actor,miscellaneous
# 1                         actress,soundtrack
# 2                actress,soundtrack,producer
# 3                    actor,writer,soundtrack
# 4                      writer,director,actor
# ...                                      ...
# 9706917  animation_department,art_department
# 9706918                                  NaN
# 9706919                      cinematographer
# 9706920                      cinematographer
# 9706921                                  NaN
#
#                                   knownForTitles
# 0        tt0050419,tt0053137,tt0072308,tt0043044
# 1        tt0071877,tt0117057,tt0038355,tt0037382
# 2        tt0054452,tt0049189,tt0059956,tt0057345
# 3        tt0077975,tt0072562,tt0080455,tt0078723
# 4        tt0069467,tt0050976,tt0083922,tt0050986
# ...                                          ...
# 9706917                                tt2455546
# 9706918                                       \N
# 9706919                                tt8736744
# 9706920                                       \N
# 9706921                                       \N
#
# [9706922 rows x 6 columns]

# %%
##Rename columns
name_basics_df = name_basics_df.rename(columns={"nconst":"nameId","knownForTitles":"assocTitleId"})

##Drop unnecessary columns (ordering)
name_basics_df = name_basics_df.drop(['birthYear','deathYear'], axis=1)

#title_basics_clean.drop_index
name_basics_df = name_basics_df.set_index(["nameId"])

name_basics_df
# Out:
#                   primaryName                    primaryProfession  \
# nameId
# nm0000001        Fred Astaire       soundtrack,actor,miscellaneous
# nm0000002       Lauren Bacall                   actress,soundtrack
# nm0000003     Brigitte Bardot          actress,soundtrack,producer
# nm0000004        John Belushi              actor,writer,soundtrack
# nm0000005      Ingmar Bergman                writer,director,actor
# ...                       ...                                  ...
# nm9993714   Romeo del Rosario  animation_department,art_department
# nm9993716       Essias Loberg                                  NaN
# nm9993717  Harikrishnan Rajan                      cinematographer
# nm9993718         Aayush Nair                      cinematographer
# nm9993719          Andre Hill                                  NaN
#
#                                       assocTitleID
# nameId
# nm0000001  tt0050419,tt0053137,tt0072308,tt0043044
# nm0000002  tt0071877,tt0117057,tt0038355,tt0037382
# nm0000003  tt0054452,tt0049189,tt0059956,tt0057345
# nm0000004  tt0077975,tt0072562,tt0080455,tt0078723
# nm0000005  tt0069467,tt0050976,tt0083922,tt0050986
# ...                                            ...
# nm9993714                                tt2455546
# nm9993716                                       \N
# nm9993717                                tt8736744
# nm9993718                                       \N
# nm9993719                                       \N
#
# [9706922 rows x 3 columns]

# %%
#Replace \N w/ N\A
name_basics_df = name_basics_df.replace('\\N', 'N\A')

##Clean up content, drop knowForTitles='N\A'
name_basics_df = name_basics_df.loc[name_basics_df['assocTitleId']!='N\A']

name_basics_df
# Out:
#                   primaryName                    primaryProfession  \
# nameId
# nm0000001        Fred Astaire       soundtrack,actor,miscellaneous
# nm0000002       Lauren Bacall                   actress,soundtrack
# nm0000003     Brigitte Bardot          actress,soundtrack,producer
# nm0000004        John Belushi              actor,writer,soundtrack
# nm0000005      Ingmar Bergman                writer,director,actor
# ...                       ...                                  ...
# nm9993708          Eli Bevins                             director
# nm9993709           Lu Bevins                             director
# nm9993713       Sambit Mishra                               writer
# nm9993714   Romeo del Rosario  animation_department,art_department
# nm9993717  Harikrishnan Rajan                      cinematographer
#
#                                       assocTitleID
# nameId
# nm0000001  tt0050419,tt0053137,tt0072308,tt0043044
# nm0000002  tt0071877,tt0117057,tt0038355,tt0037382
# nm0000003  tt0054452,tt0049189,tt0059956,tt0057345
# nm0000004  tt0077975,tt0072562,tt0080455,tt0078723
# nm0000005  tt0069467,tt0050976,tt0083922,tt0050986
# ...                                            ...
# nm9993708                      tt8744286,tt9046122
# nm9993709                                tt8744286
# nm9993713                                tt8325250
# nm9993714                                tt2455546
# nm9993717                                tt8736744
#
# [8017326 rows x 3 columns]

# %%
name_basics_df.describe()
# Out:
#         primaryName primaryProfession knownForTitles
# count       8017326           7200553        8017326
# unique      6443296             19561        4036202
# top     David Smith             actor      tt0123338
# freq            267           1628274           4794

# %%
## Merge title_basics_clean, title_ratings_df
merge_title_df = pd.merge(title_basics_clean, title_ratings_df, on="titleId", how="inner")
merge_title_df
# Out:
#                 Type               primaryTitle              originalTitle  \
# titleId
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short             Pauvre Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916576  tvEpisode           Destinee's Story           Destinee's Story
# tt9916578  tvEpisode  The Trial of Joan Collins  The Trial of Joan Collins
# tt9916720      short                  The Nun 2                  The Nun 2
# tt9916766  tvEpisode             Episode #10.15             Episode #10.15
# tt9916778  tvEpisode                     Escape                     Escape
#
#           startYear endYear runtimeMinutes                      genres  \
# titleId
# tt0000001      1894     N\A              1           Documentary,Short
# tt0000002      1892     N\A              5             Animation,Short
# tt0000003      1892     N\A              4    Animation,Comedy,Romance
# tt0000004      1892     N\A            N\A             Animation,Short
# tt0000005      1893     N\A              1                Comedy,Short
# ...             ...     ...            ...                         ...
# tt9916576      2019     N\A             85                  Reality-TV
# tt9916578      2019     N\A            N\A  Adventure,Biography,Comedy
# tt9916720      2019     N\A             10       Comedy,Horror,Mystery
# tt9916766      2019     N\A             43           Family,Reality-TV
# tt9916778      2019     N\A            N\A                       Drama
#
#            averageRating  numVotes
# titleId
# tt0000001            5.6      1550
# tt0000002            6.1       186
# tt0000003            6.5      1207
# tt0000004            6.2       113
# tt0000005            6.1      1934
# ...                  ...       ...
# tt9916576            5.9         7
# tt9916578            9.1        11
# tt9916720            5.1        41
# tt9916766            6.7        11
# tt9916778            6.9        16
#
# [974939 rows x 9 columns]

# %%
merge_title_df.describe()
# Out:
#        averageRating      numVotes
# count  974939.000000  9.749390e+05
# mean        6.897167  9.731462e+02
# std         1.399885  1.580238e+04
# min         1.000000  5.000000e+00
# 25%         6.100000  9.000000e+00
# 50%         7.100000  2.000000e+01
# 75%         7.900000  7.900000e+01
# max        10.000000  2.159745e+06

# %%
## setup mongo connection
## panda dataframe insert to mongo for each dataframe:
##     merge_title_df
##     name_basics_df
##     title_principals_df
